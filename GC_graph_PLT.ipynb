# %% [markdown]
# **Библиотека Matplotlib**

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Загрузка данных из CSV файла
df = pd.read_csv('MSFT.csv', sep=',')  # df - data frame
df.head(15)  # Выбор всех данных
# Out:
#    field1       field2        field3        field4
# 0    year     earnings       revenue  gross_profit
# 1    2018  16571000000  110360000000   72007000000
# 2    2016  16798000000   85320000000   52540000000
# 3    2015  12193000000   93580000000   60542000000
# 4    2014  22074000000   86833000000   59899000000
# 5    2019  39240000000  125843000000   82933000000
# 6    2017  21204000000   89950000000   55689000000
# 7    2013  21863000000   77849000000   57600000000
# 8    2012  16978000000   73723000000   56193000000
# 9    2011  23150000000   69943000000   54366000000
# 10   2022  72738000000  198270000000  135620000000
# 11   2021  61271000000  168088000000  115856000000
# 12   2020  44281000000  143015000000   96937000000
# 13   2023  72361000000  211915000000  146052000000
# 14   2024  88136000000  245122000000  171008000000

# %%
# Назначение переменных данным из CSV файла
a = df['year']  # Год
b = df['earnings']  # Выручка
c = df['revenue']  # Чистая прибыль
d = df['gross_profit']  # Валовая прибыль

# %% [markdown]
# Линейный график

# %%
# Создание линейного графика
plt.figure(figsize=(10, 8))  # Задание размера графика
plt.title('Финансовые показатели Microsoft Corporation с 2011-2024гг.', fontsize=16)  # Название графика
plt.xlabel('Год', color='gray')  # Название оси х
plt.ylabel('Млрд. $', color='gray')  # Название оси у
plt.plot(a, b, color='green', marker='^', markersize=6)  # Построение кривой
plt.plot(a, c, 'r--', linewidth=3, marker='o', markersize=6)  # Вариант построения кривой
plt.plot(a, d, color='blue', marker='*', markersize=7)  # Построение кривой
plt.legend(['Чистая прибыль', 'Выручка', 'Валовая прибыль'], loc=2, title='Условные обозначения:')  # Создание легенды
plt.grid()  # Отображение сетки
plt.savefig('linear_PLT.png')  # Сохранение графика в файл
plt.show()  # Вызов графика

# %% [markdown]
# ![linear_PLT.png](data:image/png;base64,...)

# %% [markdown]
# Столбчатая диаграмма

# %%
# Создание гистограммы
plt.figure(figsize=(10, 8))  # Задание размера графика
plt.title('Финансовые показатели Microsoft Corporation с 2011-2024гг.', fontsize=16)  # Название графика
plt.xlabel('Год', color='gray')  # Название оси х
plt.ylabel('Млрд. $', color='gray')  # Название оси y
plt.bar(a, c, color='r')  # Построение столбцов
plt.bar(a, d, color='b')
plt.bar(a, b, color='g')
plt.legend(['Выручка', 'Валовая прибыль', 'Чистая прибыль'], loc=2, title='Условные обозначения:')  # Создание легенды
plt.savefig('bar_PLT.png')  # Сохранение графика в файл
plt.show()  # Вызов графика

# %% [markdown]
# ![bar_PLT.png](data:image/png;base64,...)

# %% [markdown]
# Круговая даграмма

# %%
# Создание круговой диаграммы
plt.figure(figsize=(10, 10))
df[df.columns[1:4]].sum().plot.pie(autopct='%1.1f%%', labels=None, explode=[0.1, 0, 0]) # Построение круга
plt.legend(['Чистая прибыль', 'Выручка', 'Валовая прибыль'], loc=2, title='Условные обозначения:')  # Создание легенды
plt.title('Общие финансовые показатели Microsoft Corporation с 2011-2024гг.', fontsize=16)  # Название графика
plt.savefig('circular_PLT.png')  # Сохранение графика в файл
plt.show()  # Вызов графика

# %% [markdown]
# ![circular_PLT.png](data:image/png;base64,...)
